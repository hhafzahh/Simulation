# %% [markdown]
# # <center> Loading data from mongoDB <center> #

# %%
import certifi
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://test1:testone1@cluster0.s4jld.mongodb.net/Major-proj?retryWrites=true&w=majority", tlsCAFile=certifi.where())
# Database Name
db = client["Major-proj"]
 
# Collection Name
col = db["issues"]
 
x = col.find()
 
for data in x:
    print(data)
# Out:
# {'_id': ObjectId('6366040d2d1e93a8630c7d5e'), 'occuranceDateTime': '05/11/2022 14:34', 'requestorName': 'Joelyn ', 'description': 'Failure to run at dashboard', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Closed', 'remarks': ''}
# {'_id': ObjectId('636604242d1e93a8630c7d5f'), 'occuranceDateTime': '22/10/2022 18:28', 'requestorName': 'james', 'description': 'Failure to run', 'area': 'Portal - website', 'team': 'Portal Team', 'status': 'Resolved', 'remarks': 'N.A.'}
# {'_id': ObjectId('63660b8b2d1e93a8630c7d70'), 'occuranceDateTime': '05/11/2022 15:26', 'requestorName': 'Mr Tan', 'description': 'Failure to acess', 'area': 'Enterprise - Access', 'team': 'Enterprise Team', 'status': 'Pending user information', 'remarks': 'N.A.'}
# {'_id': ObjectId('636bb24f961d9377d18e92e5'), 'occuranceDateTime': '09/22/2022 22:00', 'requestorName': 'Jomes', 'description': 'potral cannto wosk', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Pending assessment', 'remarks': 'urgent'}
# {'_id': ObjectId('636bc15e961d9377d18e92e6'), 'occuranceDateTime': '05/11/2022 14:34', 'requestorName': 'Joelyn ', 'description': 'Failure to run at dashboard', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Closed', 'remarks': ''}
# {'_id': ObjectId('63a1d9b0d7a7ea3147c5f5eb'), 'occuranceDateTime': '12/05/2022 14:22', 'requestorName': 'Mysta', 'description': 'Cannot access folder', 'area': 'Enterprise - Access', 'team': 'Enterprise Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1d9ccd7a7ea3147c5f5ec'), 'occuranceDateTime': '14/05/2022 03:01', 'requestorName': 'Vox', 'description': 'Failure to make changes to file', 'area': 'Enterprise - Access', 'team': 'Enterprise Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1da0ed7a7ea3147c5f5ed'), 'occuranceDateTime': '14/05/2022 14:55', 'requestorName': 'Luca', 'description': 'Failure to create folder in portal', 'area': 'Portal - website', 'team': 'Portal Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1da3cd7a7ea3147c5f5ee'), 'occuranceDateTime': '14/05/2022 15:35', 'requestorName': 'Shu', 'description': 'Error 403', 'area': 'Enterprise - Access', 'team': 'Enterprise Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1da6bd7a7ea3147c5f5ef'), 'occuranceDateTime': '15/05/2022 17:28', 'requestorName': 'Ike', 'description': 'Error 403', 'area': 'Enterprise - Access', 'team': 'Enterprise Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1daa4d7a7ea3147c5f5f0'), 'occuranceDateTime': '15/10/2022 03:01', 'requestorName': 'Ren', 'description': 'Data not updated in dashboard, last loaded on 14 Oct', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63a1dac1d7a7ea3147c5f5f1'), 'occuranceDateTime': '15/10/2022 15:00', 'requestorName': 'Ver', 'description': 'dashboard not updated', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Pending assessment', 'remarks': 'N.A.'}
# {'_id': ObjectId('63c4368dceea59c9655c21d4'), 'occuranceDateTime': '16/01/2023 01:02', 'requestorName': 'Haffy', 'description': 'dashboard not updated', 'area': 'Analytics - Dashboard', 'team': 'Analytics Team', 'status': 'Pending user information', 'remarks': 'N.A.'}

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import numpy as np

# %%
#Present data as dataframe
df = pd.DataFrame(list(col.find()))
df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 4   636bc15e961d9377d18e92e6  05/11/2022 14:34       Joelyn
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                    Failure to acess    Enterprise - Access
# 3                                  potral cannto wosk  Analytics - Dashboard
# 4                         Failure to run at dashboard  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks
# 0    Analytics Team                    Closed
# 1       Portal Team                  Resolved    N.A.
# 2   Enterprise Team  Pending user information    N.A.
# 3    Analytics Team        Pending assessment  urgent
# 4    Analytics Team                    Closed
# 5   Enterprise Team        Pending assessment    N.A.
# 6   Enterprise Team        Pending assessment    N.A.
# 7       Portal Team        Pending assessment    N.A.
# 8   Enterprise Team        Pending assessment    N.A.
# 9   Enterprise Team        Pending assessment    N.A.
# 10   Analytics Team        Pending assessment    N.A.
# 11   Analytics Team        Pending assessment    N.A.
# 12   Analytics Team  Pending user information    N.A.

# %% [markdown]
# # <center> Data cleaning and formatting <center> #

# %% [markdown]
# <h2> Check if datetime values are valid

# %%
exceptionList = []
for index, row in df.iterrows():  
    try:
        pd.to_datetime(row['occuranceDateTime']).strftime('%d/%m/%Y %H:%M')
        #print(row['_id'], 'Date time is valid')
    
    except ValueError:
        pass
        exceptionList.append(row['_id'])
        #print(exceptionList)
        dateTime_check = exceptionList, 'Invalid datetime format.'
#         row['_id'], 'Invalid datetime format.'
        
        print(dateTime_check)

if len(exceptionList) == 0:
    dateTime_check = 'All Datetime is valid.'
    print(dateTime_check)
# Out:
# All Datetime is valid.

# %%
#Remove rows that have invalid datetime
for i in exceptionList:
    df = df[df._id != i]
df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 4   636bc15e961d9377d18e92e6  05/11/2022 14:34       Joelyn
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                    Failure to acess    Enterprise - Access
# 3                                  potral cannto wosk  Analytics - Dashboard
# 4                         Failure to run at dashboard  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks
# 0    Analytics Team                    Closed
# 1       Portal Team                  Resolved    N.A.
# 2   Enterprise Team  Pending user information    N.A.
# 3    Analytics Team        Pending assessment  urgent
# 4    Analytics Team                    Closed
# 5   Enterprise Team        Pending assessment    N.A.
# 6   Enterprise Team        Pending assessment    N.A.
# 7       Portal Team        Pending assessment    N.A.
# 8   Enterprise Team        Pending assessment    N.A.
# 9   Enterprise Team        Pending assessment    N.A.
# 10   Analytics Team        Pending assessment    N.A.
# 11   Analytics Team        Pending assessment    N.A.
# 12   Analytics Team  Pending user information    N.A.

# %% [markdown]
# <h2> Format occuranceDateTime and Business are into desirable format

# %%
#Split occuranceDateTime to OccuranceDate and OccuranceTime
df["OccuranceDate"] = pd.to_datetime(df["occuranceDateTime"]).dt.strftime('%d/%b/%Y')
df["OccuranceTime"] = pd.to_datetime(df["occuranceDateTime"]).dt.time

#Split OccuranceDate into month and year and create a seperate column for OccuranceMonth and OccuranceYear
df["OccuranceMonth"] = df["OccuranceDate"].str.split('/').str[1]
df["OccuranceYear"] = df["OccuranceDate"].str.split('/').str[-1]

#Split area and create a new column, named as 'Business Area (report) and Business Area
df[['Business Area (report)','Business Area']] = df["area"].str.split('-',expand=True)
print(df)
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 4   636bc15e961d9377d18e92e6  05/11/2022 14:34       Joelyn
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                    Failure to acess    Enterprise - Access
# 3                                  potral cannto wosk  Analytics - Dashboard
# 4                         Failure to run at dashboard  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks OccuranceDate  \
# 0    Analytics Team                    Closed           11/May/2022
# 1       Portal Team                  Resolved    N.A.   22/Oct/2022
# 2   Enterprise Team  Pending user information    N.A.   11/May/2022
# 3    Analytics Team        Pending assessment  urgent   22/Sep/2022
# 4    Analytics Team                    Closed           11/May/2022
# 5   Enterprise Team        Pending assessment    N.A.   05/Dec/2022
# 6   Enterprise Team        Pending assessment    N.A.   14/May/2022
# 7       Portal Team        Pending assessment    N.A.   14/May/2022
# 8   Enterprise Team        Pending assessment    N.A.   14/May/2022
# 9   Enterprise Team        Pending assessment    N.A.   15/May/2022
# 10   Analytics Team        Pending assessment    N.A.   15/Oct/2022
# 11   Analytics Team        Pending assessment    N.A.   15/Oct/2022
# 12   Analytics Team  Pending user information    N.A.   16/Jan/2023
#
#    OccuranceTime OccuranceMonth OccuranceYear Business Area (report)  \
# 0       14:34:00            May          2022             Analytics
# 1       18:28:00            Oct          2022                Portal
# 2       15:26:00            May          2022            Enterprise
# 3       22:00:00            Sep          2022             Analytics
# 4       14:34:00            May          2022             Analytics
# 5       14:22:00            Dec          2022            Enterprise
# 6       03:01:00            May          2022            Enterprise
# 7       14:55:00            May          2022                Portal
# 8       15:35:00            May          2022            Enterprise
# 9       17:28:00            May          2022            Enterprise
# 10      03:01:00            Oct          2022             Analytics
# 11      15:00:00            Oct          2022             Analytics
# 12      01:02:00            Jan          2023             Analytics
#
#    Business Area
# 0      Dashboard
# 1        website
# 2         Access
# 3      Dashboard
# 4      Dashboard
# 5         Access
# 6         Access
# 7        website
# 8         Access
# 9         Access
# 10     Dashboard
# 11     Dashboard
# 12     Dashboard

# %% [markdown]
# <h2> Data cleaning - handle missing values by replacing it with NaN

# %%
#Working - Handle missing values: Fill all blanks and 'N.A.' to NaN
df = df.replace(['','N.A.', 'NA','na','n.a.','nil','NIL','Nil','NIl','niL'], np.NaN)
df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 4   636bc15e961d9377d18e92e6  05/11/2022 14:34       Joelyn
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                    Failure to acess    Enterprise - Access
# 3                                  potral cannto wosk  Analytics - Dashboard
# 4                         Failure to run at dashboard  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks OccuranceDate  \
# 0    Analytics Team                    Closed     NaN   11/May/2022
# 1       Portal Team                  Resolved     NaN   22/Oct/2022
# 2   Enterprise Team  Pending user information     NaN   11/May/2022
# 3    Analytics Team        Pending assessment  urgent   22/Sep/2022
# 4    Analytics Team                    Closed     NaN   11/May/2022
# 5   Enterprise Team        Pending assessment     NaN   05/Dec/2022
# 6   Enterprise Team        Pending assessment     NaN   14/May/2022
# 7       Portal Team        Pending assessment     NaN   14/May/2022
# 8   Enterprise Team        Pending assessment     NaN   14/May/2022
# 9   Enterprise Team        Pending assessment     NaN   15/May/2022
# 10   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 11   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 12   Analytics Team  Pending user information     NaN   16/Jan/2023
#
#    OccuranceTime OccuranceMonth OccuranceYear Business Area (report)  \
# 0       14:34:00            May          2022             Analytics
# 1       18:28:00            Oct          2022                Portal
# 2       15:26:00            May          2022            Enterprise
# 3       22:00:00            Sep          2022             Analytics
# 4       14:34:00            May          2022             Analytics
# 5       14:22:00            Dec          2022            Enterprise
# 6       03:01:00            May          2022            Enterprise
# 7       14:55:00            May          2022                Portal
# 8       15:35:00            May          2022            Enterprise
# 9       17:28:00            May          2022            Enterprise
# 10      03:01:00            Oct          2022             Analytics
# 11      15:00:00            Oct          2022             Analytics
# 12      01:02:00            Jan          2023             Analytics
#
#    Business Area
# 0      Dashboard
# 1        website
# 2         Access
# 3      Dashboard
# 4      Dashboard
# 5         Access
# 6         Access
# 7        website
# 8         Access
# 9         Access
# 10     Dashboard
# 11     Dashboard
# 12     Dashboard

# %% [markdown]
# <h2> Data cleaning - handling duplicated data by removing the record

# %%
#Working - Remove dups - remove those rows that are duplicated except the '_id' column
duplicateRowsDF = df[df.duplicated(['occuranceDateTime', 'requestorName', 'description', 'area', 'team', 'status', 'remarks', 'OccuranceDate', 'OccuranceMonth', 'OccuranceYear', 'Business Area (report)', 'Business Area'])]

index = duplicateRowsDF.index

df = df.drop(index)
df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                    Failure to acess    Enterprise - Access
# 3                                  potral cannto wosk  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks OccuranceDate  \
# 0    Analytics Team                    Closed     NaN   11/May/2022
# 1       Portal Team                  Resolved     NaN   22/Oct/2022
# 2   Enterprise Team  Pending user information     NaN   11/May/2022
# 3    Analytics Team        Pending assessment  urgent   22/Sep/2022
# 5   Enterprise Team        Pending assessment     NaN   05/Dec/2022
# 6   Enterprise Team        Pending assessment     NaN   14/May/2022
# 7       Portal Team        Pending assessment     NaN   14/May/2022
# 8   Enterprise Team        Pending assessment     NaN   14/May/2022
# 9   Enterprise Team        Pending assessment     NaN   15/May/2022
# 10   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 11   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 12   Analytics Team  Pending user information     NaN   16/Jan/2023
#
#    OccuranceTime OccuranceMonth OccuranceYear Business Area (report)  \
# 0       14:34:00            May          2022             Analytics
# 1       18:28:00            Oct          2022                Portal
# 2       15:26:00            May          2022            Enterprise
# 3       22:00:00            Sep          2022             Analytics
# 5       14:22:00            Dec          2022            Enterprise
# 6       03:01:00            May          2022            Enterprise
# 7       14:55:00            May          2022                Portal
# 8       15:35:00            May          2022            Enterprise
# 9       17:28:00            May          2022            Enterprise
# 10      03:01:00            Oct          2022             Analytics
# 11      15:00:00            Oct          2022             Analytics
# 12      01:02:00            Jan          2023             Analytics
#
#    Business Area
# 0      Dashboard
# 1        website
# 2         Access
# 3      Dashboard
# 5         Access
# 6         Access
# 7        website
# 8         Access
# 9         Access
# 10     Dashboard
# 11     Dashboard
# 12     Dashboard

# %% [markdown]
# <h2> Data cleaning - ensure that business area aligns with assigned team

# %%
#Compare the "Business Area" and "team" values
teamField_checker_list = []
for index, row in df.iterrows():
    teamSplitted = row['team'].split()[0].strip()
    
    if (teamSplitted != row['Business Area (report)'].strip()):
        teamField_checker = row['_id']
        teamField_checker_list.append(row['_id'])
        formatText = 'Team field check results:'
        teamField_result = formatText + str(teamField_checker_list)
        #print('Need to fix Business Area/Assigned Team:', teamField_checker_list)
    
if len(teamField_checker_list) == 0:
    teamField_result = 'All team fields are correct.'
    
print(teamField_result)
# Out:
# All team fields are correct.

# %% [markdown]
# <h2> Data cleaning - checking for inconsistencies (typo) using spellchecker

# %%
from spellchecker import SpellChecker
from textblob import Word
from textblob import TextBlob
import re

spell = SpellChecker()
description = df["description"]

for words in description:
    descriptionTB = TextBlob(words)
    splittedWords = words.split()
    #print(splittedWords)

    #Remove punctuation signs
    #by doing 'for word in words' helps to for loop for the row is it loop at (line 8), you get 4 rows of ouput instead of 16
    cleanedWords = [word.lower() for word in splittedWords]
    cleanedWords = [re.sub(r'[^A-Za-z0-9]+', '', word) for word in splittedWords]
    #print(cleanedWords)
    
    #find those words that may be misspelled
    misspelled = list(spell.unknown(cleanedWords))
    #print("Possible list of misspelled words in the original text:\n",misspelled)
    
    #print(' '.join(misspelled))
    #missspelled_row = ' '.join(misspelled)
    #print(descriptionTB)
    for word in misspelled:
        correctWord = spell.correction(word)
        joined = [correctWord.join(correctWord)]
    descriptionTBNew = ''.join(descriptionTB.correct())
    #print(descriptionTBNew, "descriptionTBNew")
    
    #print(len(misspelled))
    if len(misspelled) > 0:
        for index, row in df.iterrows():
            if row['description'] == descriptionTB:
                #print(index)
                df.loc[index, "description"] = descriptionTBNew

df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                   Failure to access    Enterprise - Access
# 3                                  portal cannot work  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks OccuranceDate  \
# 0    Analytics Team                    Closed     NaN   11/May/2022
# 1       Portal Team                  Resolved     NaN   22/Oct/2022
# 2   Enterprise Team  Pending user information     NaN   11/May/2022
# 3    Analytics Team        Pending assessment  urgent   22/Sep/2022
# 5   Enterprise Team        Pending assessment     NaN   05/Dec/2022
# 6   Enterprise Team        Pending assessment     NaN   14/May/2022
# 7       Portal Team        Pending assessment     NaN   14/May/2022
# 8   Enterprise Team        Pending assessment     NaN   14/May/2022
# 9   Enterprise Team        Pending assessment     NaN   15/May/2022
# 10   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 11   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 12   Analytics Team  Pending user information     NaN   16/Jan/2023
#
#    OccuranceTime OccuranceMonth OccuranceYear Business Area (report)  \
# 0       14:34:00            May          2022             Analytics
# 1       18:28:00            Oct          2022                Portal
# 2       15:26:00            May          2022            Enterprise
# 3       22:00:00            Sep          2022             Analytics
# 5       14:22:00            Dec          2022            Enterprise
# 6       03:01:00            May          2022            Enterprise
# 7       14:55:00            May          2022                Portal
# 8       15:35:00            May          2022            Enterprise
# 9       17:28:00            May          2022            Enterprise
# 10      03:01:00            Oct          2022             Analytics
# 11      15:00:00            Oct          2022             Analytics
# 12      01:02:00            Jan          2023             Analytics
#
#    Business Area
# 0      Dashboard
# 1        website
# 2         Access
# 3      Dashboard
# 5         Access
# 6         Access
# 7        website
# 8         Access
# 9         Access
# 10     Dashboard
# 11     Dashboard
# 12     Dashboard

# %% [markdown]
# # <center> Sending out check report through email <center> #

# %%
from flask import Flask
from flask_mail import Mail, Message
from email.mime.text import MIMEText

app = Flask(__name__)

mail_settings = {
"MAIL_SERVER": "smtp.gmail.com",
"MAIL_USE_TLS": False,
"MAIL_USE_SSL": True,
"MAIL_PORT": 465,
"MAIL_USERNAME": "mp.hjtest@gmail.com",
"MAIL_PASSWORD": "nrqmlxfeblevvbbp"
}

app.config.update(mail_settings)
mail = Mail(app)

receiver_list = ['joelynschool@gmail.com']

with app.app_context():
    msg = Message(sender=app.config.get("MAIL_USERNAME"), recipients=receiver_list)
    msg.subject = "Automation report"
    b = str(dateTime_check)
    c = teamField_result
    result = b + '\n' + c
    msg.html = result
    mail.send(msg)

# %% [markdown]
# # <center> Writing cleaned and formatted dataframe to csv file <center> #

# %%
df
# Out:
#                          _id occuranceDateTime requestorName  \
# 0   6366040d2d1e93a8630c7d5e  05/11/2022 14:34       Joelyn
# 1   636604242d1e93a8630c7d5f  22/10/2022 18:28         james
# 2   63660b8b2d1e93a8630c7d70  05/11/2022 15:26        Mr Tan
# 3   636bb24f961d9377d18e92e5  09/22/2022 22:00         Jomes
# 5   63a1d9b0d7a7ea3147c5f5eb  12/05/2022 14:22         Mysta
# 6   63a1d9ccd7a7ea3147c5f5ec  14/05/2022 03:01           Vox
# 7   63a1da0ed7a7ea3147c5f5ed  14/05/2022 14:55          Luca
# 8   63a1da3cd7a7ea3147c5f5ee  14/05/2022 15:35           Shu
# 9   63a1da6bd7a7ea3147c5f5ef  15/05/2022 17:28           Ike
# 10  63a1daa4d7a7ea3147c5f5f0  15/10/2022 03:01           Ren
# 11  63a1dac1d7a7ea3147c5f5f1  15/10/2022 15:00           Ver
# 12  63c4368dceea59c9655c21d4  16/01/2023 01:02         Haffy
#
#                                           description                   area  \
# 0                         Failure to run at dashboard  Analytics - Dashboard
# 1                                      Failure to run       Portal - website
# 2                                   Failure to access    Enterprise - Access
# 3                                  portal cannot work  Analytics - Dashboard
# 5                                Cannot access folder    Enterprise - Access
# 6                     Failure to make changes to file    Enterprise - Access
# 7                  Failure to create folder in portal       Portal - website
# 8                                           Error 403    Enterprise - Access
# 9                                           Error 403    Enterprise - Access
# 10  Data not updated in dashboard, last loaded on ...  Analytics - Dashboard
# 11                              dashboard not updated  Analytics - Dashboard
# 12                              dashboard not updated  Analytics - Dashboard
#
#                team                    status remarks OccuranceDate  \
# 0    Analytics Team                    Closed     NaN   11/May/2022
# 1       Portal Team                  Resolved     NaN   22/Oct/2022
# 2   Enterprise Team  Pending user information     NaN   11/May/2022
# 3    Analytics Team        Pending assessment  urgent   22/Sep/2022
# 5   Enterprise Team        Pending assessment     NaN   05/Dec/2022
# 6   Enterprise Team        Pending assessment     NaN   14/May/2022
# 7       Portal Team        Pending assessment     NaN   14/May/2022
# 8   Enterprise Team        Pending assessment     NaN   14/May/2022
# 9   Enterprise Team        Pending assessment     NaN   15/May/2022
# 10   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 11   Analytics Team        Pending assessment     NaN   15/Oct/2022
# 12   Analytics Team  Pending user information     NaN   16/Jan/2023
#
#    OccuranceTime OccuranceMonth OccuranceYear Business Area (report)  \
# 0       14:34:00            May          2022             Analytics
# 1       18:28:00            Oct          2022                Portal
# 2       15:26:00            May          2022            Enterprise
# 3       22:00:00            Sep          2022             Analytics
# 5       14:22:00            Dec          2022            Enterprise
# 6       03:01:00            May          2022            Enterprise
# 7       14:55:00            May          2022                Portal
# 8       15:35:00            May          2022            Enterprise
# 9       17:28:00            May          2022            Enterprise
# 10      03:01:00            Oct          2022             Analytics
# 11      15:00:00            Oct          2022             Analytics
# 12      01:02:00            Jan          2023             Analytics
#
#    Business Area
# 0      Dashboard
# 1        website
# 2         Access
# 3      Dashboard
# 5         Access
# 6         Access
# 7        website
# 8         Access
# 9         Access
# 10     Dashboard
# 11     Dashboard
# 12     Dashboard

# %%
df.to_csv('data/MP_dataset.csv', index = False, na_rep=np.NaN)
